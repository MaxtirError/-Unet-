# %% [markdown]
# # Unet天文图像去噪增强
#
# 项目主要完成的任务是对天文图像的降噪处理
#
# 采用的方法是先在图片上产生噪声，将噪声图片视为训练集，原图像视为标签，通过Unet网络进行训练
#
# 训练平台是google colab

# %% [markdown]
# ### 产生数据
#
# 数据集在npy文件夹下。产生原始数据的函数为generate_data.py
#
# 通过generate_data.py在npy数据集中寻找所有黑色率小于0.35的204张图片。图片的列表在figurelist.txt中
#
# 同时产生一个(204,400,400)的npy文件origin.npy

# %% [markdown]
# ### 训练
#
# 先在本地文件Unet.py中写好训练的代码。
#
# 并通过tensorboard产生logs文件，在tensorboard提供的本地网页得到可视化的网络结构。
#
# 之后再google colab中上传origin.npy数据集，并在google colab用本笔记中的代码进行训练。
#
# 得到traing_Time43.h5网络模板文件
#
# 以及训练数据GolbalLoss.txt文件

# %% [markdown]
# ### 预测
#
# 再次使用generate_data.py文件避开之前采用的npy图片产生evallist.txt文件得到一些可用于预测的文件。
#
# 通过predict.py 读取evallist.txt得到数据，用和训练类似的方法产生噪声文件，并将预测的结果和噪声图片放入result文件夹中
#
# 通过result文件进行数据可视化

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !nvidia-smi
# Out:
# Fri Jul  2 01:26:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    31W /  70W |   8666MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### U-net网络结构
#
# U型对称结构，左侧是卷积层，右侧是上采样层。原文的Unet结构中，包含4个convolutional layer和对应的4个up sampling layer。
#
# ![title](train.png)
# 在原有Unet的基础上在图片拼接的第一层中加入了exptim的影响。

# %%
from numpy.lib.shape_base import expand_dims
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np

IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 1
def lrelu(x):
    return tf.maximum(x*0.2, x)

def Loss(y_true, y_pred):
    return tf.reduce_mean(tf.abs(y_true - y_pred))


def InputBlock(x, filters, time, kernel_size = 3, strides = 1, padding = 'same'):
    conv_1 = layers.Conv2D(filters= filters, kernel_size= kernel_size, \
        strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '_1')(x)
    return layers.Conv2D(filters=filters, kernel_size=kernel_size,\
        strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '_2')(conv_1)

def UpsampleAndConcat(x1, x2, filters, exp_time=None, exp=False):
    output_channels = filters * 2
    deconv = layers.Conv2DTranspose(filters= filters, kernel_size= 2, \
                          strides= 2, padding= 'same')(x1)  # 上采样（转置卷积方式）
    output_channels = filters
    if not exp:
        deconv_output = tf.concat([deconv, x2], 3)
        deconv_output.set_shape([None, None, None, output_channels * 2])
    if exp:
        cons = tf.fill(tf.shape(deconv), exp_time)
        c = tf.cast(tf.slice(cons, [0, 0, 0, 0], [-1, -1, -1, 1]), dtype= tf.float32)
        deconv_output = tf.concat([deconv, x2, c], 3)
        deconv_output.set_shape([None, None, None, output_channels * 2])
    return deconv_output

def ContractingPathBlock(x, filters, time, kernel_size = 3, strides = 1, padding = 'same'):
    down_sampling = layers.MaxPool2D((2, 2))(x)
    conv_1 = layers.Conv2D(filters= filters, kernel_size= kernel_size \
        , strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '1')(down_sampling)
    return layers.Conv2D(filters= filters, kernel_size = kernel_size \
        , strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '2')(conv_1)

def ExpansivePathBlock(x, con_feature, filters, e, time, exp = False, kernel_size = 3 \
    , strides = 1, padding = 'same'):
    concat_feature = UpsampleAndConcat(x, con_feature, filters= filters, exp_time= e, exp= exp)
    conv_1 = layers.Conv2D(filters= filters, kernel_size= kernel_size \
        , strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '1')(concat_feature)
    return layers.Conv2D(filters= filters, kernel_size= kernel_size \
        , strides= strides, padding= padding, activation= lrelu, name= 'g_conv' + time + '2')(conv_1)

def UNet(input_shape, e):
    inputs = layers.Input(input_shape)

    input_block = InputBlock(inputs, filters= 32, time= '1')

    conv_1 = ContractingPathBlock(input_block, filters= 64, time= '2')
    conv_2 = ContractingPathBlock(conv_1, filters= 128, time= '3')
    conv_3 = ContractingPathBlock(conv_2, filters= 256, time= '4')
    conv_4 = ContractingPathBlock(conv_3, filters= 512, time= '5')

    exp_4 = ExpansivePathBlock(conv_4, conv_3, filters= 256, e= e, time= '6')
    exp_3 = ExpansivePathBlock(exp_4, conv_2, filters= 128, e= e, time= '7')
    exp_2 = ExpansivePathBlock(exp_3, conv_1, filters= 64, e= e, time= '8')
    exp_1 = ExpansivePathBlock(exp_2, input_block, filters= 32, e= e, time = '9')

    outputs = layers.Conv2D(filters= 1, kernel_size= 1, activation= None, name = 'g_conv10')(exp_1)
    return tf.keras.Model(inputs= [inputs], outputs= [outputs])

def return_noise(data, exp_time, ratio= 2, dk = 3, ron = 7):
    width, height = data.shape[0:2]
    img = data * exp_time

    DN = np.random.normal(0, np.sqrt(dk*exp_time/((60*60)*ratio)), (width, height))
    RON = np.random.normal(0, ron, (width, height))
    SN = np.random.poisson(np.abs(img/ratio))

    # 以上是噪声基本格式
    noise_img = (SN + RON + DN)/(exp_time/ratio)
    noise_img = np.where(data == 0.00000000e+00, 0.00000000e+00, noise_img)
    # 使用where防止浮点数0.0被加噪

    return noise_img

def black_level(arr, max_num, level=0.3):
    """Prevent to have an image with more than some percentage of zeroes as input
       level - percentage <0,1>; 0.1/10% default"""
    arr = list(np.hstack(arr))
    per = arr.count(0)/len(arr)
    if max_num > 10:
        level = 0.35
    if per < level:
        return True
    else:
        return False

def Expand_Dim(src):
    src = expand_dims(src, axis= 0)
    src = expand_dims(src, axis= -1)
    return src

def generate_data(src, IMG_WIDTH = 256, IMG_HEIGHT = 256):
    H, W = src.shape[0:2]
    zero_level = False
    max_num = 0
    while not zero_level:
        xx = np.random.randint(0, H - IMG_HEIGHT)
        yy = np.random.randint(0, W - IMG_WIDTH)
        arr = src[xx:xx + IMG_HEIGHT, yy:yy + IMG_WIDTH]
        zero_level = black_level(arr, max_num)
        max_num += 1
    out = src[xx:xx + IMG_HEIGHT, yy:yy + IMG_WIDTH]
    out = np.where(out < 0.00000000e+00, 0.00000000e+00  , out)
    return out

# %% [markdown]
# ### 一些天文图像处理的工具函数
#
# generate_data 用于产生数据，每次在图片中随机寻找一个256*256的数据，通过blacklevel函数判断图像黑色占原图的比例，设置一个阈值之后得到一张亮度合适的图片，作为输入数据。
#
# return_noise用于产生噪声

# %%
home = '/content/gdrive/MyDrive'
origin_data_path= '/Origin.npy' 
Origins = np.load(home + origin_data_path)
Origins.shape
# Out:
# (204, 400, 400)

# %% [markdown]
# ### 网络的搭建
#
# 用tensorflow搭建网络，summary函数中可以再次得到网络结构。
#
# 优化器采用adam，学习率为1e-4

# %%
network_path = None
if network_path is None: # the first time
    model = UNet(input_shape=(IMG_WIDTH, IMG_HEIGHT, IMG_CHANNELS), e= 674)
    model.summary()
else:
  model = tf.keras.models.load_model(home + network_path, custom_objects = {'lrelu' : lrelu, 'Loss' : Loss})
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss = Loss, metrics=['accuracy'])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# g_conv1_1 (Conv2D)              (None, 256, 256, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# g_conv1_2 (Conv2D)              (None, 256, 256, 32) 9248        g_conv1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 32) 0           g_conv1_2[0][0]
# __________________________________________________________________________________________________
# g_conv21 (Conv2D)               (None, 128, 128, 64) 18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# g_conv22 (Conv2D)               (None, 128, 128, 64) 36928       g_conv21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           g_conv22[0][0]
# __________________________________________________________________________________________________
# g_conv31 (Conv2D)               (None, 64, 64, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# g_conv32 (Conv2D)               (None, 64, 64, 128)  147584      g_conv31[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           g_conv32[0][0]
# __________________________________________________________________________________________________
# g_conv41 (Conv2D)               (None, 32, 32, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# g_conv42 (Conv2D)               (None, 32, 32, 256)  590080      g_conv41[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           g_conv42[0][0]
# __________________________________________________________________________________________________
# g_conv51 (Conv2D)               (None, 16, 16, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# g_conv52 (Conv2D)               (None, 16, 16, 512)  2359808     g_conv51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 256)  524544      g_conv52[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 32, 32, 512)  0           conv2d_transpose[0][0]
#                                                                  g_conv42[0][0]
# __________________________________________________________________________________________________
# g_conv61 (Conv2D)               (None, 32, 32, 256)  1179904     tf.concat[0][0]
# __________________________________________________________________________________________________
# g_conv62 (Conv2D)               (None, 32, 32, 256)  590080      g_conv61[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 128)  131200      g_conv62[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 64, 64, 256)  0           conv2d_transpose_1[0][0]
#                                                                  g_conv32[0][0]
# __________________________________________________________________________________________________
# g_conv71 (Conv2D)               (None, 64, 64, 128)  295040      tf.concat_1[0][0]
# __________________________________________________________________________________________________
# g_conv72 (Conv2D)               (None, 64, 64, 128)  147584      g_conv71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 64) 32832       g_conv72[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 128, 128, 128 0           conv2d_transpose_2[0][0]
#                                                                  g_conv22[0][0]
# __________________________________________________________________________________________________
# g_conv81 (Conv2D)               (None, 128, 128, 64) 73792       tf.concat_2[0][0]
# __________________________________________________________________________________________________
# g_conv82 (Conv2D)               (None, 128, 128, 64) 36928       g_conv81[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 8224        g_conv82[0][0]
# __________________________________________________________________________________________________
# tf.concat_3 (TFOpLambda)        (None, 256, 256, 64) 0           conv2d_transpose_3[0][0]
#                                                                  g_conv1_2[0][0]
# __________________________________________________________________________________________________
# g_conv91 (Conv2D)               (None, 256, 256, 32) 18464       tf.concat_3[0][0]
# __________________________________________________________________________________________________
# g_conv92 (Conv2D)               (None, 256, 256, 32) 9248        g_conv91[0][0]
# __________________________________________________________________________________________________
# g_conv10 (Conv2D)               (None, 256, 256, 1)  33          g_conv92[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def text_write_data(file, l):
    """save parameters into text file"""
    file = open(home + file, "a+")
    for name in l:
        file.write(str(name) + "\n")
    file.close

# %% [markdown]
# ### 训练方法
#
# 从数据集中导入。
#
# 每次打乱数据集的顺序。
#
# 从数据集中的每张图片中随机产生5张噪声图片进行训练。
#
# 每50张图片记录一次Loss
#
# 总共训练了43轮
#
# 其中在本地的code文件中采用了tesorboard产生了网络的结构可视化文件（也就是网络结构中的那张图。）

# %%
batch_size = 1
epochs = 1
def Expand(x):
  return np.expand_dims(np.expand_dims(x, axis= 0), axis= -1)
Loss = []
g_Loss = []
Lass_time = 20
for Time in range(Lass_time, 5000):
    cnt = 0
    for origin in np.random.permutation(Origins):
        out = generate_data(origin)
        out_train = Expand(out)
        for r in range(2, 6):
            img = return_noise(out, 674, ratio= r)
            tf.keras.backend.set_value(model.optimizer.lr, 1e-4)
            results = model.fit(Expand(img), out_train, batch_size= batch_size, epochs= epochs)
            g_Loss.append(results.history['loss'][-1])
        
        cnt += 1
        if cnt % 50 == 0:
          print(cnt)
          Loss.append(np.mean(g_Loss))
          g_Loss = []
    if Time % 1 == 0:
        network_path = '/traing'+ '_Time' + str(Time) + '_loss' + str(results.history['loss'][-1]) + '_acu' \
            + str(results.history['accuracy'][-1])
        model.save(home + network_path + '.h5')
        text_write_data("/GlobalLoss.txt", Loss)
        Loss = []
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2147 - accuracy: 0.1445
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2599 - accuracy: 0.1445
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2987 - accuracy: 0.1445
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3346 - accuracy: 0.1445
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2304 - accuracy: 0.0845
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2783 - accuracy: 0.0845
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3221 - accuracy: 0.0845
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3588 - accuracy: 0.0845
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5388 - accuracy: 0.2296
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5694 - accuracy: 0.2435
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6478 - accuracy: 0.2038
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8835 - accuracy: 0.2690
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2038 - accuracy: 0.3240
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3507 - accuracy: 0.3222
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3875 - accuracy: 0.3197
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3250 - accuracy: 0.3224
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2571 - accuracy: 0.1241
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4638 - accuracy: 0.1245
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4506 - accuracy: 0.1244
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3607 - accuracy: 0.1241
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5561 - accuracy: 0.2757
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3451 - accuracy: 0.2774
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4493 - accuracy: 0.2776
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4253 - accuracy: 0.2772
# 1/1 [==============================] - 0s 44ms/step - loss: 0.3282 - accuracy: 0.1879
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4653 - accuracy: 0.1880
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3676 - accuracy: 0.1880
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5210 - accuracy: 0.1878
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3444 - accuracy: 0.1839
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9096 - accuracy: 0.1839
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6142 - accuracy: 0.1839
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9632 - accuracy: 0.1838
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5877 - accuracy: 0.2136
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2535 - accuracy: 0.2136
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5469 - accuracy: 0.2136
# 1/1 [==============================] - 0s 59ms/step - loss: 0.5946 - accuracy: 0.2136
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5967 - accuracy: 0.2593
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8137 - accuracy: 0.2254
# 1/1 [==============================] - 0s 47ms/step - loss: 0.7350 - accuracy: 0.2535
# 1/1 [==============================] - 0s 48ms/step - loss: 0.6468 - accuracy: 0.2871
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3776 - accuracy: 0.1056
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3586 - accuracy: 0.1056
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4283 - accuracy: 0.1056
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4123 - accuracy: 0.1056
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3614 - accuracy: 0.0821
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3127 - accuracy: 0.0821
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4114 - accuracy: 0.0821
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3772 - accuracy: 0.0820
# 150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3581 - accuracy: 0.1880
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3795 - accuracy: 0.1880
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3614 - accuracy: 0.1880
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4564 - accuracy: 0.1880
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1854 - accuracy: 0.2323
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2516 - accuracy: 0.2322
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2682 - accuracy: 0.2322
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2922 - accuracy: 0.2323
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1946 - accuracy: 0.2011
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2156 - accuracy: 0.2011
# 1/1 [==============================] - 0s 51ms/step - loss: 0.2472 - accuracy: 0.2011
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2831 - accuracy: 0.2011
# 1/1 [==============================] - 0s 43ms/step - loss: 0.1891 - accuracy: 0.3140
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2427 - accuracy: 0.3141
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2563 - accuracy: 0.3141
# 1/1 [==============================] - 0s 49ms/step - loss: 0.2890 - accuracy: 0.3140
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2199 - accuracy: 0.1226
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2510 - accuracy: 0.1226
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3024 - accuracy: 0.1226
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3233 - accuracy: 0.1226
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2019 - accuracy: 0.1341
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2383 - accuracy: 0.1341
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2696 - accuracy: 0.1342
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3014 - accuracy: 0.1343
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2410 - accuracy: 0.1254
# 1/1 [==============================] - 0s 54ms/step - loss: 0.